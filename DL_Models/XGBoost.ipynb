# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameer-Tahir/Project_DS/blob/main/DL_Models/XGBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Sameer-Tahir/Project_DS.git
# Out:
# Cloning into 'Project_DS'...
# remote: Enumerating objects: 302, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (156/156), done.
# remote: Total 302 (delta 73), reused 6 (delta 6), pack-reused 113 (from 1)
# Receiving objects: 100% (302/302), 16.75 MiB | 9.10 MiB/s, done.
# Resolving deltas: 100% (97/97), done.

# %%
# !pip install optuna optuna-dashboard
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.5.0)
# Collecting optuna-dashboard
#   Downloading optuna_dashboard-0.19.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.16.5)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.2)
# Collecting bottle>=0.13.0 (from optuna-dashboard)
#   Downloading bottle-0.13.4-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from optuna-dashboard) (1.6.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->optuna-dashboard) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->optuna-dashboard) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->optuna-dashboard) (3.6.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna_dashboard-0.19.0-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 36.7 MB/s eta 0:00:00
# Downloading bottle-0.13.4-py2.py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: bottle, optuna-dashboard
# Successfully installed bottle-0.13.4 optuna-dashboard-0.19.0

# %%
# Import libraries
import pandas as pd   # data processing
import numpy as np    # linear algebra
import seaborn as sns
import matplotlib.pyplot as plt
import json
from tensorflow.keras import layers, models, callbacks
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, classification_report
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import json
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from tensorflow.keras import layers, models, callbacks
import numpy as np, joblib
from sklearn.metrics import precision_recall_fscore_support
import tensorflow as tf
from tensorflow.keras import layers, models
import xgboost as xgb
import lightgbm as lgb
from xgboost.callback import EarlyStopping
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %%
# -----------------------
# Load your splits
# -----------------------
train_df = pd.read_csv("dfk1_train.csv")
val_df   = pd.read_csv("dfk1_val.csv")
test_df  = pd.read_csv("dfk1_test.csv")

# %%
# !unzip -o dl_preprocessed.zip
# Out:
# Archive:  dl_preprocessed.zip
#   inflating: dl_data_windows.npz
#   inflating: label_encoder.pkl
#   inflating: scaler.pkl

# %%
# Load arrays
data = np.load("dl_data_windows.npz", allow_pickle=True)
X_train, y_train = data["X_train"], data["y_train"]
X_val, y_val     = data["X_val"],   data["y_val"]
X_test, y_test   = data["X_test"],  data["y_test"]
feature_cols     = data["feature_cols"].tolist()
classes          = data["classes"]

# Load encoder & scaler
le = joblib.load("label_encoder.pkl")
scaler = joblib.load("scaler.pkl")

print("✅ Data loaded successfully")
print("Train:", X_train.shape, y_train.shape)
print("Val:",   X_val.shape, y_val.shape)
print("Test:",  X_test.shape, y_test.shape)
print("Classes:", classes)
# Out:
# ✅ Data loaded successfully
# Train: (4835, 6, 222) (4835,)
# Val: (591, 6, 222) (591,)
# Test: (590, 6, 222) (590,)
# Classes: ['aggressive-scan' 'cryptojacking' 'icmp-flood' 'icmp-fragmentation'
#  'icmp-fragmentation_old' 'none' 'os-fingerprinting' 'os-scan' 'port-scan'
#  'push-ack-flood' 'serice-detection' 'service-detection' 'syn-flood'
#  'syn-stealth' 'synonymous-ip-flood' 'tcp-flood' 'udp-flood' 'vuln-scan']

# %%
import xgboost as xgb
print(xgb.__version__)
# Out:
# 3.0.4

# %%
# -----------------------
# Flatten time-series to tabular for boosting
# -----------------------
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat = X_val.reshape(X_val.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

# ================================================================
# XGBoost
# ================================================================
xgb_model = xgb.XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="multi:softmax",
    num_class=len(classes),
    eval_metric="mlogloss",
    tree_method="hist"
)

# Train with evaluation set
xgb_model.fit(
    X_train_flat, y_train,
    eval_set=[(X_val_flat, y_val)],
    verbose=True
)

# Best iteration workaround
results = xgb_model.evals_result()
val_loss = results["validation_0"]["mlogloss"]
best_iter = int(np.argmin(val_loss))
print(f"Best iteration (manual): {best_iter}")

# Predict
y_pred_xgb = xgb_model.predict(X_test_flat, iteration_range=(0, best_iter+1))

# Metrics
acc_xgb = accuracy_score(y_test, y_pred_xgb)
f1_xgb = f1_score(y_test, y_pred_xgb, average="macro")
report_xgb = classification_report(y_test, y_pred_xgb, target_names=classes, zero_division=0)
cm_xgb = confusion_matrix(y_test, y_pred_xgb)

print("\n✅ XGBoost Results")
print("Accuracy:", acc_xgb)
print("Macro-F1:", f1_xgb)
print(report_xgb)

# Confusion Matrix
plt.figure(figsize=(8, 6))
plt.imshow(cm_xgb, cmap="Blues")
plt.title("XGBoost Confusion Matrix")
plt.colorbar()
plt.xticks(np.arange(len(classes)), classes, rotation=90)
plt.yticks(np.arange(len(classes)), classes)
plt.xlabel("Predicted")
plt.ylabel("Actual")
for i in range(cm_xgb.shape[0]):
    for j in range(cm_xgb.shape[1]):
        plt.text(j, i, cm_xgb[i, j], ha="center", va="center",
                 color="red" if cm_xgb[i, j] > cm_xgb.max()/2 else "black")
plt.tight_layout()
plt.savefig("XGBoost_confusion_matrix.png")
plt.show()

# Per-class F1 (XGBoost)
prec, rec, f1, support = precision_recall_fscore_support(y_test, y_pred_xgb, zero_division=0)
plt.figure(figsize=(12, 5))
plt.bar(classes, f1, color="skyblue")
plt.xticks(rotation=90)
plt.title("Per-Class F1 Scores (XGBoost)")
plt.ylabel("F1 Score")
plt.tight_layout()
plt.savefig("XGBoost_f1_per_class.png")
plt.show()

# Save Results
results_xgb = {
    "accuracy": float(acc_xgb),
    "macro_f1": float(f1_xgb),
    "report": report_xgb,
    "confusion_matrix": cm_xgb.tolist()
}
with open("results_xgboost.json", "w") as f:
    json.dump(results_xgb, f, indent=4)
# Out:
# [0]	validation_0-mlogloss:2.53294
# [1]	validation_0-mlogloss:2.29571
# [2]	validation_0-mlogloss:2.11347
# [3]	validation_0-mlogloss:1.96366
# [4]	validation_0-mlogloss:1.83579
# [5]	validation_0-mlogloss:1.72497
# [6]	validation_0-mlogloss:1.62875
# [7]	validation_0-mlogloss:1.54270
# [8]	validation_0-mlogloss:1.46555
# [9]	validation_0-mlogloss:1.39480
# [10]	validation_0-mlogloss:1.33139
# [11]	validation_0-mlogloss:1.27255
# [12]	validation_0-mlogloss:1.21686
# [13]	validation_0-mlogloss:1.16671
# [14]	validation_0-mlogloss:1.12054
# [15]	validation_0-mlogloss:1.07602
# [16]	validation_0-mlogloss:1.03448
# [17]	validation_0-mlogloss:0.99605
# [18]	validation_0-mlogloss:0.95941
# [19]	validation_0-mlogloss:0.92562
# [20]	validation_0-mlogloss:0.89315
# [21]	validation_0-mlogloss:0.86323
# [22]	validation_0-mlogloss:0.83589
# [23]	validation_0-mlogloss:0.80884
# [24]	validation_0-mlogloss:0.78226
# [25]	validation_0-mlogloss:0.75776
# [26]	validation_0-mlogloss:0.73429
# [27]	validation_0-mlogloss:0.71290
# [28]	validation_0-mlogloss:0.69249
# [29]	validation_0-mlogloss:0.67288
# [30]	validation_0-mlogloss:0.65464
# [31]	validation_0-mlogloss:0.63712
# [32]	validation_0-mlogloss:0.62048
# [33]	validation_0-mlogloss:0.60463
# [34]	validation_0-mlogloss:0.58970
# [35]	validation_0-mlogloss:0.57597
# [36]	validation_0-mlogloss:0.56198
# [37]	validation_0-mlogloss:0.54959
# [38]	validation_0-mlogloss:0.53749
# [39]	validation_0-mlogloss:0.52651
# [40]	validation_0-mlogloss:0.51469
# [41]	validation_0-mlogloss:0.50350
# [42]	validation_0-mlogloss:0.49347
# [43]	validation_0-mlogloss:0.48385
# [44]	validation_0-mlogloss:0.47382
# [45]	validation_0-mlogloss:0.46509
# [46]	validation_0-mlogloss:0.45671
# [47]	validation_0-mlogloss:0.44877
# [48]	validation_0-mlogloss:0.44072
# [49]	validation_0-mlogloss:0.43319
# [50]	validation_0-mlogloss:0.42622
# [51]	validation_0-mlogloss:0.42009
# [52]	validation_0-mlogloss:0.41385
# [53]	validation_0-mlogloss:0.40765
# [54]	validation_0-mlogloss:0.40204
# [55]	validation_0-mlogloss:0.39644
# [56]	validation_0-mlogloss:0.39137
# [57]	validation_0-mlogloss:0.38652
# [58]	validation_0-mlogloss:0.38125
# [59]	validation_0-mlogloss:0.37650
# [60]	validation_0-mlogloss:0.37187
# [61]	validation_0-mlogloss:0.36792
# [62]	validation_0-mlogloss:0.36403
# [63]	validation_0-mlogloss:0.36043
# [64]	validation_0-mlogloss:0.35690
# [65]	validation_0-mlogloss:0.35336
# [66]	validation_0-mlogloss:0.35028
# [67]	validation_0-mlogloss:0.34719
# [68]	validation_0-mlogloss:0.34389
# [69]	validation_0-mlogloss:0.34117
# [70]	validation_0-mlogloss:0.33765
# [71]	validation_0-mlogloss:0.33563
# [72]	validation_0-mlogloss:0.33333
# [73]	validation_0-mlogloss:0.33078
# [74]	validation_0-mlogloss:0.32844
# [75]	validation_0-mlogloss:0.32644
# [76]	validation_0-mlogloss:0.32438
# [77]	validation_0-mlogloss:0.32276
# [78]	validation_0-mlogloss:0.32072
# [79]	validation_0-mlogloss:0.31897
# [80]	validation_0-mlogloss:0.31685
# [81]	validation_0-mlogloss:0.31513
# [82]	validation_0-mlogloss:0.31377
# [83]	validation_0-mlogloss:0.31217
# [84]	validation_0-mlogloss:0.31060
# [85]	validation_0-mlogloss:0.30924
# [86]	validation_0-mlogloss:0.30759
# [87]	validation_0-mlogloss:0.30639
# [88]	validation_0-mlogloss:0.30503
# [89]	validation_0-mlogloss:0.30391
# [90]	validation_0-mlogloss:0.30276
# [91]	validation_0-mlogloss:0.30137
# [92]	validation_0-mlogloss:0.30049
# [93]	validation_0-mlogloss:0.29955
# [94]	validation_0-mlogloss:0.29853
# [95]	validation_0-mlogloss:0.29779
# [96]	validation_0-mlogloss:0.29727
# [97]	validation_0-mlogloss:0.29653
# [98]	validation_0-mlogloss:0.29501
# [99]	validation_0-mlogloss:0.29375
# [100]	validation_0-mlogloss:0.29283
# [101]	validation_0-mlogloss:0.29223
# [102]	validation_0-mlogloss:0.29122
# [103]	validation_0-mlogloss:0.29094
# [104]	validation_0-mlogloss:0.29054
# [105]	validation_0-mlogloss:0.28945
# [106]	validation_0-mlogloss:0.28887
# [107]	validation_0-mlogloss:0.28814
# [108]	validation_0-mlogloss:0.28765
# [109]	validation_0-mlogloss:0.28695
# [110]	validation_0-mlogloss:0.28659
# [111]	validation_0-mlogloss:0.28626
# [112]	validation_0-mlogloss:0.28547
# [113]	validation_0-mlogloss:0.28444
# [114]	validation_0-mlogloss:0.28396
# [115]	validation_0-mlogloss:0.28362
# [116]	validation_0-mlogloss:0.28358
# [117]	validation_0-mlogloss:0.28364
# [118]	validation_0-mlogloss:0.28324
# [119]	validation_0-mlogloss:0.28321
# [120]	validation_0-mlogloss:0.28300
# [121]	validation_0-mlogloss:0.28252
# [122]	validation_0-mlogloss:0.28216
# [123]	validation_0-mlogloss:0.28177
# [124]	validation_0-mlogloss:0.28154
# [125]	validation_0-mlogloss:0.28150
# [126]	validation_0-mlogloss:0.28120
# [127]	validation_0-mlogloss:0.28099
# [128]	validation_0-mlogloss:0.28059
# [129]	validation_0-mlogloss:0.27990
# [130]	validation_0-mlogloss:0.27997
# [131]	validation_0-mlogloss:0.27971
# [132]	validation_0-mlogloss:0.27955
# [133]	validation_0-mlogloss:0.27954
# [134]	validation_0-mlogloss:0.27919
# [135]	validation_0-mlogloss:0.27881
# [136]	validation_0-mlogloss:0.27870
# [137]	validation_0-mlogloss:0.27872
# [138]	validation_0-mlogloss:0.27854
# [139]	validation_0-mlogloss:0.27845
# [140]	validation_0-mlogloss:0.27846
# [141]	validation_0-mlogloss:0.27852
# [142]	validation_0-mlogloss:0.27832
# [143]	validation_0-mlogloss:0.27811
# [144]	validation_0-mlogloss:0.27817
# [145]	validation_0-mlogloss:0.27812
# [146]	validation_0-mlogloss:0.27843
# [147]	validation_0-mlogloss:0.27834
# [148]	validation_0-mlogloss:0.27809
# [149]	validation_0-mlogloss:0.27827
# [150]	validation_0-mlogloss:0.27818
# [151]	validation_0-mlogloss:0.27837
# [152]	validation_0-mlogloss:0.27841
# [153]	validation_0-mlogloss:0.27835
# [154]	validation_0-mlogloss:0.27803
# [155]	validation_0-mlogloss:0.27802
# [156]	validation_0-mlogloss:0.27817
# [157]	validation_0-mlogloss:0.27795
# [158]	validation_0-mlogloss:0.27798
# [159]	validation_0-mlogloss:0.27795
# [160]	validation_0-mlogloss:0.27768
# [161]	validation_0-mlogloss:0.27783
# [162]	validation_0-mlogloss:0.27736
# [163]	validation_0-mlogloss:0.27761
# [164]	validation_0-mlogloss:0.27733
# [165]	validation_0-mlogloss:0.27709
# [166]	validation_0-mlogloss:0.27704
# [167]	validation_0-mlogloss:0.27680
# [168]	validation_0-mlogloss:0.27671
# [169]	validation_0-mlogloss:0.27682
# [170]	validation_0-mlogloss:0.27660
# [171]	validation_0-mlogloss:0.27664
# [172]	validation_0-mlogloss:0.27690
# [173]	validation_0-mlogloss:0.27714
# [174]	validation_0-mlogloss:0.27714
# [175]	validation_0-mlogloss:0.27677
# [176]	validation_0-mlogloss:0.27684
# [177]	validation_0-mlogloss:0.27697
# [178]	validation_0-mlogloss:0.27697
# [179]	validation_0-mlogloss:0.27734
# [180]	validation_0-mlogloss:0.27769
# [181]	validation_0-mlogloss:0.27745
# [182]	validation_0-mlogloss:0.27736
# [183]	validation_0-mlogloss:0.27750
# [184]	validation_0-mlogloss:0.27782
# [185]	validation_0-mlogloss:0.27798
# [186]	validation_0-mlogloss:0.27821
# [187]	validation_0-mlogloss:0.27811
# [188]	validation_0-mlogloss:0.27795
# [189]	validation_0-mlogloss:0.27814
# [190]	validation_0-mlogloss:0.27806
# [191]	validation_0-mlogloss:0.27843
# [192]	validation_0-mlogloss:0.27853
# [193]	validation_0-mlogloss:0.27861
# [194]	validation_0-mlogloss:0.27863
# [195]	validation_0-mlogloss:0.27845
# [196]	validation_0-mlogloss:0.27849
# [197]	validation_0-mlogloss:0.27821
# [198]	validation_0-mlogloss:0.27831
# [199]	validation_0-mlogloss:0.27850
# [200]	validation_0-mlogloss:0.27889
# [201]	validation_0-mlogloss:0.27881
# [202]	validation_0-mlogloss:0.27920
# [203]	validation_0-mlogloss:0.27927
# [204]	validation_0-mlogloss:0.27924
# [205]	validation_0-mlogloss:0.27956
# [206]	validation_0-mlogloss:0.27949
# [207]	validation_0-mlogloss:0.27972
# [208]	validation_0-mlogloss:0.27971
# [209]	validation_0-mlogloss:0.27994
# [210]	validation_0-mlogloss:0.28010
# [211]	validation_0-mlogloss:0.28022
# [212]	validation_0-mlogloss:0.28010
# [213]	validation_0-mlogloss:0.28027
# [214]	validation_0-mlogloss:0.28020
# [215]	validation_0-mlogloss:0.28025
# [216]	validation_0-mlogloss:0.28041
# [217]	validation_0-mlogloss:0.28047
# [218]	validation_0-mlogloss:0.28077
# [219]	validation_0-mlogloss:0.28089
# [220]	validation_0-mlogloss:0.28108
# [221]	validation_0-mlogloss:0.28110
# [222]	validation_0-mlogloss:0.28133
# [223]	validation_0-mlogloss:0.28165
# [224]	validation_0-mlogloss:0.28151
# [225]	validation_0-mlogloss:0.28159
# [226]	validation_0-mlogloss:0.28180
# [227]	validation_0-mlogloss:0.28169
# [228]	validation_0-mlogloss:0.28177
# [229]	validation_0-mlogloss:0.28178
# [230]	validation_0-mlogloss:0.28180
# [231]	validation_0-mlogloss:0.28198
# [232]	validation_0-mlogloss:0.28224
# [233]	validation_0-mlogloss:0.28233
# [234]	validation_0-mlogloss:0.28241
# [235]	validation_0-mlogloss:0.28270
# [236]	validation_0-mlogloss:0.28266
# [237]	validation_0-mlogloss:0.28281
# [238]	validation_0-mlogloss:0.28295
# [239]	validation_0-mlogloss:0.28290
# [240]	validation_0-mlogloss:0.28303
# [241]	validation_0-mlogloss:0.28304
# [242]	validation_0-mlogloss:0.28329
# [243]	validation_0-mlogloss:0.28317
# [244]	validation_0-mlogloss:0.28308
# [245]	validation_0-mlogloss:0.28290
# [246]	validation_0-mlogloss:0.28303
# [247]	validation_0-mlogloss:0.28296
# [248]	validation_0-mlogloss:0.28290
# [249]	validation_0-mlogloss:0.28275
# [250]	validation_0-mlogloss:0.28283
# [251]	validation_0-mlogloss:0.28267
# [252]	validation_0-mlogloss:0.28307
# [253]	validation_0-mlogloss:0.28306
# [254]	validation_0-mlogloss:0.28329
# [255]	validation_0-mlogloss:0.28359
# [256]	validation_0-mlogloss:0.28375
# [257]	validation_0-mlogloss:0.28387
# [258]	validation_0-mlogloss:0.28401
# [259]	validation_0-mlogloss:0.28414
# [260]	validation_0-mlogloss:0.28399
# [261]	validation_0-mlogloss:0.28420
# [262]	validation_0-mlogloss:0.28426
# [263]	validation_0-mlogloss:0.28427
# [264]	validation_0-mlogloss:0.28445
# [265]	validation_0-mlogloss:0.28437
# [266]	validation_0-mlogloss:0.28445
# [267]	validation_0-mlogloss:0.28456
# [268]	validation_0-mlogloss:0.28471
# [269]	validation_0-mlogloss:0.28498
# [270]	validation_0-mlogloss:0.28512
# [271]	validation_0-mlogloss:0.28515
# [272]	validation_0-mlogloss:0.28527
# [273]	validation_0-mlogloss:0.28551
# [274]	validation_0-mlogloss:0.28560
# [275]	validation_0-mlogloss:0.28575
# [276]	validation_0-mlogloss:0.28590
# [277]	validation_0-mlogloss:0.28607
# [278]	validation_0-mlogloss:0.28620
# [279]	validation_0-mlogloss:0.28633
# [280]	validation_0-mlogloss:0.28603
# [281]	validation_0-mlogloss:0.28625
# [282]	validation_0-mlogloss:0.28615
# [283]	validation_0-mlogloss:0.28621
# [284]	validation_0-mlogloss:0.28622
# [285]	validation_0-mlogloss:0.28634
# [286]	validation_0-mlogloss:0.28626
# [287]	validation_0-mlogloss:0.28635
# [288]	validation_0-mlogloss:0.28646
# [289]	validation_0-mlogloss:0.28650
# [290]	validation_0-mlogloss:0.28649
# [291]	validation_0-mlogloss:0.28675
# [292]	validation_0-mlogloss:0.28668
# [293]	validation_0-mlogloss:0.28682
# [294]	validation_0-mlogloss:0.28695
# [295]	validation_0-mlogloss:0.28711
# [296]	validation_0-mlogloss:0.28713
# [297]	validation_0-mlogloss:0.28723
# [298]	validation_0-mlogloss:0.28717
# [299]	validation_0-mlogloss:0.28720
# Best iteration (manual): 170
#
# ✅ XGBoost Results
# Accuracy: 0.9169491525423729
# Macro-F1: 0.778417041720127
#                         precision    recall  f1-score   support
#
#        aggressive-scan       0.67      0.78      0.72        18
#          cryptojacking       1.00      1.00      1.00       165
#             icmp-flood       0.69      0.85      0.76        13
#     icmp-fragmentation       1.00      1.00      1.00        13
# icmp-fragmentation_old       0.33      0.17      0.22         6
#                   none       1.00      1.00      1.00       220
#      os-fingerprinting       0.67      0.77      0.71        13
#                os-scan       0.67      0.67      0.67         6
#              port-scan       0.74      0.74      0.74        19
#         push-ack-flood       1.00      1.00      1.00        12
#       serice-detection       0.71      0.83      0.77         6
#      service-detection       0.46      0.43      0.44        14
#              syn-flood       1.00      1.00      1.00        13
#            syn-stealth       0.69      0.53      0.60        17
#    synonymous-ip-flood       1.00      1.00      1.00        12
#              tcp-flood       0.92      1.00      0.96        12
#              udp-flood       1.00      0.75      0.86        12
#              vuln-scan       0.55      0.58      0.56        19
#
#               accuracy                           0.92       590
#              macro avg       0.78      0.78      0.78       590
#           weighted avg       0.92      0.92      0.92       590

# %% [markdown]
# ✅ XGBoost Results
# Accuracy: 0.9169491525423729
# Macro-F1: 0.778417041720127

# %%
# -----------------------
# Flatten + Feature Engineering
# -----------------------
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import json

# ✅ Safety check
try:
    X_train, X_val, X_test
    y_train, y_val, y_test
    classes
except NameError:
    raise ValueError("❌ Dataset not found. Please load and split your dataset first.")

# -----------------------
# Flatten raw sequences
# -----------------------
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat   = X_val.reshape(X_val.shape[0], -1)
X_test_flat  = X_test.reshape(X_test.shape[0], -1)

# -----------------------
# Feature extraction
# -----------------------
def extract_features(X):
    feats = []
    for sample in X:  # sample shape: (window, n_features)
        stats = []
        stats.extend(np.mean(sample, axis=0))
        stats.extend(np.std(sample, axis=0))
        stats.extend(np.min(sample, axis=0))
        stats.extend(np.max(sample, axis=0))
        stats.extend(np.median(sample, axis=0))
        feats.append(stats)
    return np.array(feats)

X_train_feats = extract_features(X_train)
X_val_feats   = extract_features(X_val)
X_test_feats  = extract_features(X_test)

# Concatenate raw + engineered
X_train_all = np.hstack([X_train_flat, X_train_feats])
X_val_all   = np.hstack([X_val_flat, X_val_feats])
X_test_all  = np.hstack([X_test_flat, X_test_feats])

# Normalize
scaler = StandardScaler()
X_train_all = scaler.fit_transform(X_train_all)
X_val_all   = scaler.transform(X_val_all)
X_test_all  = scaler.transform(X_test_all)

print("✅ Final feature shape:", X_train_all.shape)

# ================================================================
# Hyperparameter Tuning with Optuna (efficient version)
# ================================================================
import optuna
import xgboost as xgb

dtrain_opt = xgb.DMatrix(X_train_all, label=y_train)

def objective(trial):
    params = {
        "objective": "multi:softprob",
        "num_class": len(classes),
        "eval_metric": "mlogloss",
        "tree_method": "hist",
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
    }
    cv_results = xgb.cv(
        params,
        dtrain_opt,
        num_boost_round=300,
        nfold=3,
        early_stopping_rounds=20,
        seed=42,
        metrics="mlogloss",
        verbose_eval=False
    )
    return 1.0 - cv_results["test-mlogloss-mean"].min()

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=5, timeout=900)  # 5 trials or 15 mins

best_params = study.best_params
print("✅ Best hyperparameters:", best_params)

# ================================================================
# Train Final Model (using xgboost.train for early stopping)
# ================================================================
from xgboost import DMatrix, train

dtrain = DMatrix(X_train_all, label=y_train)
dval   = DMatrix(X_val_all, label=y_val)
dtest  = DMatrix(X_test_all, label=y_test)

params = {
    **best_params,
    "objective": "multi:softmax",  # classification
    "num_class": len(classes),
    "eval_metric": "mlogloss",
    "tree_method": "hist"
}

evals = [(dtrain, "train"), (dval, "val")]

print("🚀 Training XGBoost with early stopping...")
xgb_model = train(
    params,
    dtrain,
    num_boost_round=300,
    evals=evals,
    early_stopping_rounds=20,
    verbose_eval=True
)

# Predict
y_pred_xgb = xgb_model.predict(dtest)

# ================================================================
# Evaluation
# ================================================================
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix, precision_recall_fscore_support

acc_xgb = accuracy_score(y_test, y_pred_xgb)
f1_xgb  = f1_score(y_test, y_pred_xgb, average="macro")
report_xgb = classification_report(y_test, y_pred_xgb, target_names=classes, zero_division=0)
cm_xgb = confusion_matrix(y_test, y_pred_xgb)

print("\n✅ XGBoost Results (Tuned)")
print("Accuracy:", acc_xgb)
print("Macro-F1:", f1_xgb)
print(report_xgb)

# Confusion Matrix
plt.figure(figsize=(8, 6))
plt.imshow(cm_xgb, cmap="Blues")
plt.title("XGBoost Confusion Matrix (Tuned)")
plt.colorbar()
plt.xticks(np.arange(len(classes)), classes, rotation=90)
plt.yticks(np.arange(len(classes)), classes)
plt.xlabel("Predicted")
plt.ylabel("Actual")
for i in range(cm_xgb.shape[0]):
    for j in range(cm_xgb.shape[1]):
        plt.text(j, i, cm_xgb[i, j], ha="center", va="center",
                 color="red" if cm_xgb[i, j] > cm_xgb.max()/2 else "black")
plt.tight_layout()
plt.savefig("XGBoost_confusion_matrix_tuned.png")
plt.show()

# Per-class F1
prec, rec, f1, support = precision_recall_fscore_support(y_test, y_pred_xgb, zero_division=0)
plt.figure(figsize=(12, 5))
plt.bar(classes, f1, color="skyblue")
plt.xticks(rotation=90)
plt.title("Per-Class F1 Scores (XGBoost, Tuned)")
plt.ylabel("F1 Score")
plt.tight_layout()
plt.savefig("XGBoost_f1_per_class_tuned.png")
plt.show()

# ================================================================
# Feature Importance
# ================================================================
xgb.plot_importance(xgb_model, max_num_features=20, importance_type="gain")
plt.title("XGBoost Feature Importance (Top 20)")
plt.tight_layout()
plt.savefig("XGBoost_feature_importance.png")
plt.show()

# Save Results
results_xgb = {
    "accuracy": float(acc_xgb),
    "macro_f1": float(f1_xgb),
    "report": report_xgb,
    "confusion_matrix": cm_xgb.tolist(),
    "best_params": best_params
}
with open("results_xgboost_tuned.json", "w") as f:
    json.dump(results_xgb, f, indent=4)

print("📂 Saved: tuned model results, confusion matrix, F1 plots, feature importance")
# Out:
# ✅ Final feature shape: (4835, 2442)
# [I 2025-09-15 18:24:01,943] A new study created in memory with name: no-name-8a521227-73a2-45c2-be7e-8badacd0822c
# [I 2025-09-15 18:34:37,571] Trial 0 finished with value: 0.7052884768549714 and parameters: {'max_depth': 10, 'learning_rate': 0.0993208488451505, 'subsample': 0.8388990578530451, 'colsample_bytree': 0.679279002440623, 'gamma': 1.331193461661389, 'min_child_weight': 5}. Best is trial 0 with value: 0.7052884768549714.
# [I 2025-09-15 19:04:19,159] Trial 1 finished with value: 0.6674619240449533 and parameters: {'max_depth': 6, 'learning_rate': 0.01538298367956373, 'subsample': 0.8044354184197565, 'colsample_bytree': 0.9903971765821369, 'gamma': 1.1109296924426175, 'min_child_weight': 9}. Best is trial 0 with value: 0.7052884768549714.
# ✅ Best hyperparameters: {'max_depth': 10, 'learning_rate': 0.0993208488451505, 'subsample': 0.8388990578530451, 'colsample_bytree': 0.679279002440623, 'gamma': 1.331193461661389, 'min_child_weight': 5}
# 🚀 Training XGBoost with early stopping...
# [0]	train-mlogloss:2.20440	val-mlogloss:2.21811
# [1]	train-mlogloss:1.86989	val-mlogloss:1.89679
# [2]	train-mlogloss:1.63742	val-mlogloss:1.67323
# [3]	train-mlogloss:1.45219	val-mlogloss:1.49590
# [4]	train-mlogloss:1.30158	val-mlogloss:1.35412
# [5]	train-mlogloss:1.17582	val-mlogloss:1.23710
# [6]	train-mlogloss:1.06685	val-mlogloss:1.13451
# [7]	train-mlogloss:0.97309	val-mlogloss:1.04734
# [8]	train-mlogloss:0.89069	val-mlogloss:0.97213
# [9]	train-mlogloss:0.81712	val-mlogloss:0.90470
# [10]	train-mlogloss:0.75130	val-mlogloss:0.84490
# [11]	train-mlogloss:0.69288	val-mlogloss:0.79267
# [12]	train-mlogloss:0.64039	val-mlogloss:0.74603
# [13]	train-mlogloss:0.59375	val-mlogloss:0.70408
# [14]	train-mlogloss:0.55141	val-mlogloss:0.66540
# [15]	train-mlogloss:0.51246	val-mlogloss:0.63234
# [16]	train-mlogloss:0.47679	val-mlogloss:0.60121
# [17]	train-mlogloss:0.44493	val-mlogloss:0.57497
# [18]	train-mlogloss:0.41557	val-mlogloss:0.55026
# [19]	train-mlogloss:0.38897	val-mlogloss:0.52710
# [20]	train-mlogloss:0.36410	val-mlogloss:0.50586
# [21]	train-mlogloss:0.34192	val-mlogloss:0.48522
# [22]	train-mlogloss:0.32113	val-mlogloss:0.46895
# [23]	train-mlogloss:0.30257	val-mlogloss:0.45323
# [24]	train-mlogloss:0.28546	val-mlogloss:0.43856
# [25]	train-mlogloss:0.26929	val-mlogloss:0.42494
# [26]	train-mlogloss:0.25459	val-mlogloss:0.41268
# [27]	train-mlogloss:0.24108	val-mlogloss:0.40146
# [28]	train-mlogloss:0.22836	val-mlogloss:0.38977
# [29]	train-mlogloss:0.21659	val-mlogloss:0.37972
# [30]	train-mlogloss:0.20640	val-mlogloss:0.37152
# [31]	train-mlogloss:0.19689	val-mlogloss:0.36341
# [32]	train-mlogloss:0.18739	val-mlogloss:0.35633
# [33]	train-mlogloss:0.17947	val-mlogloss:0.34993
# [34]	train-mlogloss:0.17151	val-mlogloss:0.34451
# [35]	train-mlogloss:0.16401	val-mlogloss:0.33866
# [36]	train-mlogloss:0.15789	val-mlogloss:0.33337
# [37]	train-mlogloss:0.15241	val-mlogloss:0.32940
# [38]	train-mlogloss:0.14752	val-mlogloss:0.32519
# [39]	train-mlogloss:0.14280	val-mlogloss:0.32072
# [40]	train-mlogloss:0.13807	val-mlogloss:0.31679
# [41]	train-mlogloss:0.13390	val-mlogloss:0.31346
# [42]	train-mlogloss:0.12993	val-mlogloss:0.31047
# [43]	train-mlogloss:0.12643	val-mlogloss:0.30719
# [44]	train-mlogloss:0.12302	val-mlogloss:0.30485
# [45]	train-mlogloss:0.11977	val-mlogloss:0.30242
# [46]	train-mlogloss:0.11700	val-mlogloss:0.30046
# [47]	train-mlogloss:0.11451	val-mlogloss:0.29783
# [48]	train-mlogloss:0.11228	val-mlogloss:0.29597
# [49]	train-mlogloss:0.11019	val-mlogloss:0.29416
# [50]	train-mlogloss:0.10834	val-mlogloss:0.29233
# [51]	train-mlogloss:0.10659	val-mlogloss:0.29098
# [52]	train-mlogloss:0.10486	val-mlogloss:0.28961
# [53]	train-mlogloss:0.10350	val-mlogloss:0.28811
# [54]	train-mlogloss:0.10178	val-mlogloss:0.28725
# [55]	train-mlogloss:0.10036	val-mlogloss:0.28599
# [56]	train-mlogloss:0.09898	val-mlogloss:0.28546
# [57]	train-mlogloss:0.09799	val-mlogloss:0.28465
# [58]	train-mlogloss:0.09676	val-mlogloss:0.28400
# [59]	train-mlogloss:0.09595	val-mlogloss:0.28331
# [60]	train-mlogloss:0.09492	val-mlogloss:0.28235
# [61]	train-mlogloss:0.09406	val-mlogloss:0.28140
# [62]	train-mlogloss:0.09345	val-mlogloss:0.28107
# [63]	train-mlogloss:0.09285	val-mlogloss:0.28061
# [64]	train-mlogloss:0.09244	val-mlogloss:0.28014
# [65]	train-mlogloss:0.09203	val-mlogloss:0.27977
# [66]	train-mlogloss:0.09166	val-mlogloss:0.27936
# [67]	train-mlogloss:0.09106	val-mlogloss:0.27925
# [68]	train-mlogloss:0.09071	val-mlogloss:0.27885
# [69]	train-mlogloss:0.09050	val-mlogloss:0.27866
# [70]	train-mlogloss:0.09017	val-mlogloss:0.27823
# [71]	train-mlogloss:0.08990	val-mlogloss:0.27801
# [72]	train-mlogloss:0.08943	val-mlogloss:0.27787
# [73]	train-mlogloss:0.08918	val-mlogloss:0.27760
# [74]	train-mlogloss:0.08905	val-mlogloss:0.27734
# [75]	train-mlogloss:0.08891	val-mlogloss:0.27727
# [76]	train-mlogloss:0.08857	val-mlogloss:0.27672
# [77]	train-mlogloss:0.08844	val-mlogloss:0.27651
# [78]	train-mlogloss:0.08834	val-mlogloss:0.27636
# [79]	train-mlogloss:0.08823	val-mlogloss:0.27631
# [80]	train-mlogloss:0.08814	val-mlogloss:0.27617
# [81]	train-mlogloss:0.08808	val-mlogloss:0.27617
# [82]	train-mlogloss:0.08796	val-mlogloss:0.27601
# [83]	train-mlogloss:0.08789	val-mlogloss:0.27593
# [84]	train-mlogloss:0.08769	val-mlogloss:0.27582
# [85]	train-mlogloss:0.08766	val-mlogloss:0.27589
# [86]	train-mlogloss:0.08765	val-mlogloss:0.27587
# [87]	train-mlogloss:0.08751	val-mlogloss:0.27585
# [88]	train-mlogloss:0.08745	val-mlogloss:0.27580
# [89]	train-mlogloss:0.08729	val-mlogloss:0.27621
# [90]	train-mlogloss:0.08701	val-mlogloss:0.27650
# [91]	train-mlogloss:0.08696	val-mlogloss:0.27648
# [92]	train-mlogloss:0.08692	val-mlogloss:0.27654
# [93]	train-mlogloss:0.08683	val-mlogloss:0.27659
# [94]	train-mlogloss:0.08683	val-mlogloss:0.27656
# [95]	train-mlogloss:0.08681	val-mlogloss:0.27649
# [96]	train-mlogloss:0.08672	val-mlogloss:0.27645
# [97]	train-mlogloss:0.08656	val-mlogloss:0.27638
# [98]	train-mlogloss:0.08645	val-mlogloss:0.27640
# [99]	train-mlogloss:0.08643	val-mlogloss:0.27639
# [100]	train-mlogloss:0.08635	val-mlogloss:0.27664
# [101]	train-mlogloss:0.08632	val-mlogloss:0.27662
# [102]	train-mlogloss:0.08623	val-mlogloss:0.27664
# [103]	train-mlogloss:0.08608	val-mlogloss:0.27640
# [104]	train-mlogloss:0.08601	val-mlogloss:0.27631
# [105]	train-mlogloss:0.08596	val-mlogloss:0.27621
# [106]	train-mlogloss:0.08594	val-mlogloss:0.27627
# [107]	train-mlogloss:0.08594	val-mlogloss:0.27627
#
# ✅ XGBoost Results (Tuned)
# Accuracy: 0.9101694915254237
# Macro-F1: 0.7723977216069767
#                         precision    recall  f1-score   support
#
#        aggressive-scan       0.72      0.72      0.72        18
#          cryptojacking       1.00      1.00      1.00       165
#             icmp-flood       0.71      0.77      0.74        13
#     icmp-fragmentation       1.00      1.00      1.00        13
# icmp-fragmentation_old       0.40      0.33      0.36         6
#                   none       1.00      1.00      1.00       220
#      os-fingerprinting       0.60      0.69      0.64        13
#                os-scan       0.71      0.83      0.77         6
#              port-scan       0.61      0.58      0.59        19
#         push-ack-flood       1.00      1.00      1.00        12
#       serice-detection       0.67      0.67      0.67         6
#      service-detection       0.42      0.36      0.38        14
#              syn-flood       1.00      1.00      1.00        13
#            syn-stealth       0.63      0.71      0.67        17
#    synonymous-ip-flood       1.00      0.92      0.96        12
#              tcp-flood       0.92      1.00      0.96        12
#              udp-flood       1.00      0.83      0.91        12
#              vuln-scan       0.53      0.53      0.53        19
#
#               accuracy                           0.91       590
#              macro avg       0.77      0.77      0.77       590
#           weighted avg       0.91      0.91      0.91       590
# 📂 Saved: tuned model results, confusion matrix, F1 plots, feature importance

# %%
# -----------------------
# Flatten + Feature Engineering
# -----------------------
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Flatten raw
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat = X_val.reshape(X_val.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

# Add simple statistical features from each time-series window
def extract_features(X):
    feats = []
    for sample in X:
        stats = []
        stats.extend(np.mean(sample, axis=0))
        stats.extend(np.std(sample, axis=0))
        stats.extend(np.min(sample, axis=0))
        stats.extend(np.max(sample, axis=0))
        stats.extend(np.median(sample, axis=0))
        feats.append(stats)
    return np.array(feats)

X_train_feats = extract_features(X_train)
X_val_feats = extract_features(X_val)
X_test_feats = extract_features(X_test)

# Concatenate raw + engineered
X_train_all = np.hstack([X_train_flat, X_train_feats])
X_val_all = np.hstack([X_val_flat, X_val_feats])
X_test_all = np.hstack([X_test_flat, X_test_feats])

# Normalize features
scaler = StandardScaler()
X_train_all = scaler.fit_transform(X_train_all)
X_val_all = scaler.transform(X_val_all)
X_test_all = scaler.transform(X_test_all)

print("Final feature shape:", X_train_all.shape)

# ================================================================
# Hyperparameter Tuning with Optuna (efficient version)
# ================================================================
import optuna
import xgboost as xgb

dtrain = xgb.DMatrix(X_train_all, label=y_train)

def objective(trial):
    params = {
        "objective": "multi:softmax",
        "num_class": len(classes),
        "eval_metric": "mlogloss",
        "tree_method": "hist",
        "n_estimators": trial.suggest_int("n_estimators", 200, 600),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
    }
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=600,
        nfold=3,
        early_stopping_rounds=20,
        seed=42,
        metrics="mlogloss",
        verbose_eval=False
    )
    return 1.0 - cv_results["test-mlogloss-mean"].min()

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=15, timeout=3600)  # ⏱️ limit to 1 hour or 15 trials
best_params = study.best_params
print("Best hyperparameters:", best_params)

# ================================================================
# Train Final Model with Class Weights
# ================================================================
from sklearn.utils.class_weight import compute_class_weight

weights = compute_class_weight(class_weight="balanced", classes=np.unique(y_train), y=y_train)
scale_pos_weight = np.max(weights) / np.min(weights)
best_params["scale_pos_weight"] = scale_pos_weight

xgb_model = xgb.XGBClassifier(**best_params)
xgb_model.fit(X_train_all, y_train, eval_set=[(X_val_all, y_val)], verbose=True)

# Predict
y_pred_xgb = xgb_model.predict(X_test_all)

# ================================================================
# Evaluation
# ================================================================
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix, precision_recall_fscore_support
import matplotlib.pyplot as plt
import json

acc_xgb = accuracy_score(y_test, y_pred_xgb)
f1_xgb = f1_score(y_test, y_pred_xgb, average="macro")
report_xgb = classification_report(y_test, y_pred_xgb, target_names=classes, zero_division=0)
cm_xgb = confusion_matrix(y_test, y_pred_xgb)

print("\n✅ XGBoost Results (Tuned)")
print("Accuracy:", acc_xgb)
print("Macro-F1:", f1_xgb)
print(report_xgb)

# Confusion Matrix
plt.figure(figsize=(8, 6))
plt.imshow(cm_xgb, cmap="Blues")
plt.title("XGBoost Confusion Matrix (Tuned)")
plt.colorbar()
plt.xticks(np.arange(len(classes)), classes, rotation=90)
plt.yticks(np.arange(len(classes)), classes)
plt.xlabel("Predicted")
plt.ylabel("Actual")
for i in range(cm_xgb.shape[0]):
    for j in range(cm_xgb.shape[1]):
        plt.text(j, i, cm_xgb[i, j], ha="center", va="center",
                 color="red" if cm_xgb[i, j] > cm_xgb.max()/2 else "black")
plt.tight_layout()
plt.savefig("XGBoost_confusion_matrix_tuned.png")
plt.show()

# Per-class F1
prec, rec, f1, support = precision_recall_fscore_support(y_test, y_pred_xgb, zero_division=0)
plt.figure(figsize=(12, 5))
plt.bar(classes, f1, color="skyblue")
plt.xticks(rotation=90)
plt.title("Per-Class F1 Scores (XGBoost, Tuned)")
plt.ylabel("F1 Score")
plt.tight_layout()
plt.savefig("XGBoost_f1_per_class_tuned.png")
plt.show()

# ================================================================
# Interpretability with SHAP
# ================================================================
import shap
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_test_all[:200])  # ⚡ limit for speed

shap.summary_plot(shap_values, X_test_all[:200], feature_names=[f"f{i}" for i in range(X_test_all.shape[1])])

# Save Results
results_xgb = {
    "accuracy": float(acc_xgb),
    "macro_f1": float(f1_xgb),
    "report": report_xgb,
    "confusion_matrix": cm_xgb.tolist(),
    "best_params": best_params
}
with open("results_xgboost_tuned.json", "w") as f:
    json.dump(results_xgb, f, indent=4)

print("📂 Saved: tuned model results, confusion matrix, F1 plots, SHAP plots")
# Out:
# Final feature shape: (4835, 2442)
# [I 2025-09-15 10:14:41,294] A new study created in memory with name: no-name-4587a9bc-a6a3-484e-9d46-a8dd3e1bb787
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:209: UserWarning: [10:14:42] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   return getattr(self.bst, name)(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:215: UserWarning: [10:14:49] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   self.bst.update(self.dtrain, iteration, fobj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:215: UserWarning: [10:14:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   self.bst.update(self.dtrain, iteration, fobj)
# [I 2025-09-15 10:49:58,810] Trial 0 finished with value: 0.6570029080638597 and parameters: {'n_estimators': 442, 'max_depth': 10, 'learning_rate': 0.018551469207731073, 'subsample': 0.8086413944739708, 'colsample_bytree': 0.8237730234650388, 'gamma': 4.85394426885575, 'min_child_weight': 9}. Best is trial 0 with value: 0.6570029080638597.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:209: UserWarning: [10:49:59] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   return getattr(self.bst, name)(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:215: UserWarning: [10:50:01] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   self.bst.update(self.dtrain, iteration, fobj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:215: UserWarning: [10:50:03] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   self.bst.update(self.dtrain, iteration, fobj)
# [I 2025-09-15 10:57:34,461] Trial 1 finished with value: 0.6884231480301388 and parameters: {'n_estimators': 412, 'max_depth': 6, 'learning_rate': 0.1485354434427429, 'subsample': 0.7578502654194663, 'colsample_bytree': 0.6180492583523175, 'gamma': 1.5295745424851703, 'min_child_weight': 10}. Best is trial 1 with value: 0.6884231480301388.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:209: UserWarning: [10:57:34] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   return getattr(self.bst, name)(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:215: UserWarning: [10:57:37] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   self.bst.update(self.dtrain, iteration, fobj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:215: UserWarning: [10:57:41] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   self.bst.update(self.dtrain, iteration, fobj)
# [I 2025-09-15 11:11:00,799] Trial 2 finished with value: 0.7111374852537441 and parameters: {'n_estimators': 540, 'max_depth': 4, 'learning_rate': 0.09806053484398389, 'subsample': 0.9016920425518182, 'colsample_bytree': 0.6307972181040903, 'gamma': 1.6299798167869517, 'min_child_weight': 2}. Best is trial 2 with value: 0.7111374852537441.
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:209: UserWarning: [11:11:01] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   return getattr(self.bst, name)(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:215: UserWarning: [11:11:04] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   self.bst.update(self.dtrain, iteration, fobj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:215: UserWarning: [11:11:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "n_estimators" } are not used.
#
#   self.bst.update(self.dtrain, iteration, fobj)
# [I 2025-09-15 11:18:11,147] Trial 3 finished with value: 0.6784610469291961 and parameters: {'n_estimators': 468, 'max_depth': 9, 'learning_rate': 0.14251354893135515, 'subsample': 0.9765138809933402, 'colsample_bytree': 0.8483008062556547, 'gamma': 3.8703232409917865, 'min_child_weight': 4}. Best is trial 2 with value: 0.7111374852537441.
# Best hyperparameters: {'n_estimators': 540, 'max_depth': 4, 'learning_rate': 0.09806053484398389, 'subsample': 0.9016920425518182, 'colsample_bytree': 0.6307972181040903, 'gamma': 1.6299798167869517, 'min_child_weight': 2}
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [11:18:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [0]	validation_0-mlogloss:2.20593
# [1]	validation_0-mlogloss:1.88719
# [2]	validation_0-mlogloss:1.66549
# [3]	validation_0-mlogloss:1.49338
# [4]	validation_0-mlogloss:1.35469
# [5]	validation_0-mlogloss:1.23970
# [6]	validation_0-mlogloss:1.14085
# [7]	validation_0-mlogloss:1.05525
# [8]	validation_0-mlogloss:0.98002
# [9]	validation_0-mlogloss:0.91352
# [10]	validation_0-mlogloss:0.85424
# [11]	validation_0-mlogloss:0.80269
# [12]	validation_0-mlogloss:0.75523
# [13]	validation_0-mlogloss:0.71322
# [14]	validation_0-mlogloss:0.67638
# [15]	validation_0-mlogloss:0.64248
# [16]	validation_0-mlogloss:0.61133
# [17]	validation_0-mlogloss:0.58348
# [18]	validation_0-mlogloss:0.55769
# [19]	validation_0-mlogloss:0.53443
# [20]	validation_0-mlogloss:0.51311
# [21]	validation_0-mlogloss:0.49293
# [22]	validation_0-mlogloss:0.47579
# [23]	validation_0-mlogloss:0.45965
# [24]	validation_0-mlogloss:0.44534
# [25]	validation_0-mlogloss:0.43144
# [26]	validation_0-mlogloss:0.42047
# [27]	validation_0-mlogloss:0.40834
# [28]	validation_0-mlogloss:0.39764
# [29]	validation_0-mlogloss:0.38858
# [30]	validation_0-mlogloss:0.37959
# [31]	validation_0-mlogloss:0.37081
# [32]	validation_0-mlogloss:0.36345
# [33]	validation_0-mlogloss:0.35648
# [34]	validation_0-mlogloss:0.35004
# [35]	validation_0-mlogloss:0.34527
# [36]	validation_0-mlogloss:0.33957
# [37]	validation_0-mlogloss:0.33440
# [38]	validation_0-mlogloss:0.32993
# [39]	validation_0-mlogloss:0.32601
# [40]	validation_0-mlogloss:0.32187
# [41]	validation_0-mlogloss:0.31893
# [42]	validation_0-mlogloss:0.31568
# [43]	validation_0-mlogloss:0.31254
# [44]	validation_0-mlogloss:0.30958
# [45]	validation_0-mlogloss:0.30755
# [46]	validation_0-mlogloss:0.30498
# [47]	validation_0-mlogloss:0.30291
# [48]	validation_0-mlogloss:0.30108
# [49]	validation_0-mlogloss:0.29969
# [50]	validation_0-mlogloss:0.29829
# [51]	validation_0-mlogloss:0.29685
# [52]	validation_0-mlogloss:0.29472
# [53]	validation_0-mlogloss:0.29382
# [54]	validation_0-mlogloss:0.29259
# [55]	validation_0-mlogloss:0.29156
# [56]	validation_0-mlogloss:0.29076
# [57]	validation_0-mlogloss:0.28958
# [58]	validation_0-mlogloss:0.28919
# [59]	validation_0-mlogloss:0.28875
# [60]	validation_0-mlogloss:0.28817
# [61]	validation_0-mlogloss:0.28769
# [62]	validation_0-mlogloss:0.28733
# [63]	validation_0-mlogloss:0.28702
# [64]	validation_0-mlogloss:0.28666
# [65]	validation_0-mlogloss:0.28638
# [66]	validation_0-mlogloss:0.28627
# [67]	validation_0-mlogloss:0.28607
# [68]	validation_0-mlogloss:0.28590
# [69]	validation_0-mlogloss:0.28534
# [70]	validation_0-mlogloss:0.28530
# [71]	validation_0-mlogloss:0.28515
# [72]	validation_0-mlogloss:0.28514
# [73]	validation_0-mlogloss:0.28500
# [74]	validation_0-mlogloss:0.28480
# [75]	validation_0-mlogloss:0.28450
# [76]	validation_0-mlogloss:0.28431
# [77]	validation_0-mlogloss:0.28406
# [78]	validation_0-mlogloss:0.28393
# [79]	validation_0-mlogloss:0.28384
# [80]	validation_0-mlogloss:0.28375
# [81]	validation_0-mlogloss:0.28381
# [82]	validation_0-mlogloss:0.28343
# [83]	validation_0-mlogloss:0.28341
# [84]	validation_0-mlogloss:0.28337
# [85]	validation_0-mlogloss:0.28332
# [86]	validation_0-mlogloss:0.28330
# [87]	validation_0-mlogloss:0.28370
# [88]	validation_0-mlogloss:0.28366
# [89]	validation_0-mlogloss:0.28340
# [90]	validation_0-mlogloss:0.28331
# [91]	validation_0-mlogloss:0.28329
# [92]	validation_0-mlogloss:0.28360
# [93]	validation_0-mlogloss:0.28366
# [94]	validation_0-mlogloss:0.28363
# [95]	validation_0-mlogloss:0.28342
# [96]	validation_0-mlogloss:0.28368
# [97]	validation_0-mlogloss:0.28368
# [98]	validation_0-mlogloss:0.28379
# [99]	validation_0-mlogloss:0.28377
# [100]	validation_0-mlogloss:0.28370
# [101]	validation_0-mlogloss:0.28379
# [102]	validation_0-mlogloss:0.28357
# [103]	validation_0-mlogloss:0.28352
# [104]	validation_0-mlogloss:0.28353
# [105]	validation_0-mlogloss:0.28371
# [106]	validation_0-mlogloss:0.28349
# [107]	validation_0-mlogloss:0.28349
# [108]	validation_0-mlogloss:0.28346
# [109]	validation_0-mlogloss:0.28348
# [110]	validation_0-mlogloss:0.28367
# [111]	validation_0-mlogloss:0.28369
# [112]	validation_0-mlogloss:0.28377
# [113]	validation_0-mlogloss:0.28376
# [114]	validation_0-mlogloss:0.28350
# [115]	validation_0-mlogloss:0.28352
# [116]	validation_0-mlogloss:0.28367
# [117]	validation_0-mlogloss:0.28363
# [118]	validation_0-mlogloss:0.28352
# [119]	validation_0-mlogloss:0.28351
# [120]	validation_0-mlogloss:0.28352
# [121]	validation_0-mlogloss:0.28349
# [122]	validation_0-mlogloss:0.28348
# [123]	validation_0-mlogloss:0.28347
# [124]	validation_0-mlogloss:0.28344
# [125]	validation_0-mlogloss:0.28344
# [126]	validation_0-mlogloss:0.28343
# [127]	validation_0-mlogloss:0.28334
# [128]	validation_0-mlogloss:0.28335
# [129]	validation_0-mlogloss:0.28334
# [130]	validation_0-mlogloss:0.28323
# [131]	validation_0-mlogloss:0.28336
# [132]	validation_0-mlogloss:0.28318
# [133]	validation_0-mlogloss:0.28311
# [134]	validation_0-mlogloss:0.28311
# [135]	validation_0-mlogloss:0.28306
# [136]	validation_0-mlogloss:0.28312
# [137]	validation_0-mlogloss:0.28316
# [138]	validation_0-mlogloss:0.28277
# [139]	validation_0-mlogloss:0.28274
# [140]	validation_0-mlogloss:0.28272
# [141]	validation_0-mlogloss:0.28282
# [142]	validation_0-mlogloss:0.28286
# [143]	validation_0-mlogloss:0.28285
# [144]	validation_0-mlogloss:0.28294
# [145]	validation_0-mlogloss:0.28292
# [146]	validation_0-mlogloss:0.28289
# [147]	validation_0-mlogloss:0.28290
# [148]	validation_0-mlogloss:0.28288
# [149]	validation_0-mlogloss:0.28289
# [150]	validation_0-mlogloss:0.28290
# [151]	validation_0-mlogloss:0.28311
# [152]	validation_0-mlogloss:0.28311
# [153]	validation_0-mlogloss:0.28311
# [154]	validation_0-mlogloss:0.28311
# [155]	validation_0-mlogloss:0.28309
# [156]	validation_0-mlogloss:0.28309
# [157]	validation_0-mlogloss:0.28310
# [158]	validation_0-mlogloss:0.28305
# [159]	validation_0-mlogloss:0.28304
# [160]	validation_0-mlogloss:0.28312
# [161]	validation_0-mlogloss:0.28312
# [162]	validation_0-mlogloss:0.28308
# [163]	validation_0-mlogloss:0.28309
# [164]	validation_0-mlogloss:0.28311
# [165]	validation_0-mlogloss:0.28306
# [166]	validation_0-mlogloss:0.28310
# [167]	validation_0-mlogloss:0.28310
# [168]	validation_0-mlogloss:0.28293
# [169]	validation_0-mlogloss:0.28292
# [170]	validation_0-mlogloss:0.28307
# [171]	validation_0-mlogloss:0.28308
# [172]	validation_0-mlogloss:0.28308
# [173]	validation_0-mlogloss:0.28309
# [174]	validation_0-mlogloss:0.28301
# [175]	validation_0-mlogloss:0.28293
# [176]	validation_0-mlogloss:0.28291
# [177]	validation_0-mlogloss:0.28291
# [178]	validation_0-mlogloss:0.28290
# [179]	validation_0-mlogloss:0.28290
# [180]	validation_0-mlogloss:0.28290
# [181]	validation_0-mlogloss:0.28289
# [182]	validation_0-mlogloss:0.28272
# [183]	validation_0-mlogloss:0.28273
# [184]	validation_0-mlogloss:0.28284
# [185]	validation_0-mlogloss:0.28284
# [186]	validation_0-mlogloss:0.28285
# [187]	validation_0-mlogloss:0.28283
# [188]	validation_0-mlogloss:0.28288
# [189]	validation_0-mlogloss:0.28287
# [190]	validation_0-mlogloss:0.28285
# [191]	validation_0-mlogloss:0.28283
# [192]	validation_0-mlogloss:0.28284
# [193]	validation_0-mlogloss:0.28264
# [194]	validation_0-mlogloss:0.28264
# [195]	validation_0-mlogloss:0.28262
# [196]	validation_0-mlogloss:0.28262
# [197]	validation_0-mlogloss:0.28270
# [198]	validation_0-mlogloss:0.28270
# [199]	validation_0-mlogloss:0.28270
# [200]	validation_0-mlogloss:0.28269
# [201]	validation_0-mlogloss:0.28267
# [202]	validation_0-mlogloss:0.28266
# [203]	validation_0-mlogloss:0.28274
# [204]	validation_0-mlogloss:0.28272
# [205]	validation_0-mlogloss:0.28271
# [206]	validation_0-mlogloss:0.28271
# [207]	validation_0-mlogloss:0.28270
# [208]	validation_0-mlogloss:0.28276
# [209]	validation_0-mlogloss:0.28276
# [210]	validation_0-mlogloss:0.28275
# [211]	validation_0-mlogloss:0.28278
# [212]	validation_0-mlogloss:0.28275
# [213]	validation_0-mlogloss:0.28279
# [214]	validation_0-mlogloss:0.28278
# [215]	validation_0-mlogloss:0.28281
# [216]	validation_0-mlogloss:0.28282
# [217]	validation_0-mlogloss:0.28283
# [218]	validation_0-mlogloss:0.28283
# [219]	validation_0-mlogloss:0.28295
# [220]	validation_0-mlogloss:0.28287
# [221]	validation_0-mlogloss:0.28285
# [222]	validation_0-mlogloss:0.28284
# [223]	validation_0-mlogloss:0.28266
# [224]	validation_0-mlogloss:0.28269
# [225]	validation_0-mlogloss:0.28271
# [226]	validation_0-mlogloss:0.28266
# [227]	validation_0-mlogloss:0.28267
# [228]	validation_0-mlogloss:0.28266
# [229]	validation_0-mlogloss:0.28266
# [230]	validation_0-mlogloss:0.28265
# [231]	validation_0-mlogloss:0.28260
# [232]	validation_0-mlogloss:0.28248
# [233]	validation_0-mlogloss:0.28248
# [234]	validation_0-mlogloss:0.28248
# [235]	validation_0-mlogloss:0.28245
# [236]	validation_0-mlogloss:0.28244
# [237]	validation_0-mlogloss:0.28237
# [238]	validation_0-mlogloss:0.28238
# [239]	validation_0-mlogloss:0.28223
# [240]	validation_0-mlogloss:0.28222
# [241]	validation_0-mlogloss:0.28223
# [242]	validation_0-mlogloss:0.28232
# [243]	validation_0-mlogloss:0.28231
# [244]	validation_0-mlogloss:0.28228
# [245]	validation_0-mlogloss:0.28226
# [246]	validation_0-mlogloss:0.28223
# [247]	validation_0-mlogloss:0.28224
# [248]	validation_0-mlogloss:0.28225
# [249]	validation_0-mlogloss:0.28226
# [250]	validation_0-mlogloss:0.28225
# [251]	validation_0-mlogloss:0.28226
# [252]	validation_0-mlogloss:0.28228
# [253]	validation_0-mlogloss:0.28230
# [254]	validation_0-mlogloss:0.28230
# [255]	validation_0-mlogloss:0.28232
# [256]	validation_0-mlogloss:0.28232
# [257]	validation_0-mlogloss:0.28233
# [258]	validation_0-mlogloss:0.28232
# [259]	validation_0-mlogloss:0.28229
# [260]	validation_0-mlogloss:0.28240
# [261]	validation_0-mlogloss:0.28231
# [262]	validation_0-mlogloss:0.28230
# [263]	validation_0-mlogloss:0.28236
# [264]	validation_0-mlogloss:0.28256
# [265]	validation_0-mlogloss:0.28258
# [266]	validation_0-mlogloss:0.28277
# [267]	validation_0-mlogloss:0.28276
# [268]	validation_0-mlogloss:0.28266
# [269]	validation_0-mlogloss:0.28264
# [270]	validation_0-mlogloss:0.28264
# [271]	validation_0-mlogloss:0.28266
# [272]	validation_0-mlogloss:0.28266
# [273]	validation_0-mlogloss:0.28268
# [274]	validation_0-mlogloss:0.28270
# [275]	validation_0-mlogloss:0.28271
# [276]	validation_0-mlogloss:0.28272
# [277]	validation_0-mlogloss:0.28273
# [278]	validation_0-mlogloss:0.28274
# [279]	validation_0-mlogloss:0.28254
# [280]	validation_0-mlogloss:0.28254
# [281]	validation_0-mlogloss:0.28253
# [282]	validation_0-mlogloss:0.28253
# [283]	validation_0-mlogloss:0.28255
# [284]	validation_0-mlogloss:0.28256
# [285]	validation_0-mlogloss:0.28254
# [286]	validation_0-mlogloss:0.28257
# [287]	validation_0-mlogloss:0.28263
# [288]	validation_0-mlogloss:0.28265
# [289]	validation_0-mlogloss:0.28264
# [290]	validation_0-mlogloss:0.28265
# [291]	validation_0-mlogloss:0.28254
# [292]	validation_0-mlogloss:0.28256
# [293]	validation_0-mlogloss:0.28255
# [294]	validation_0-mlogloss:0.28252
# [295]	validation_0-mlogloss:0.28253
# [296]	validation_0-mlogloss:0.28253
# [297]	validation_0-mlogloss:0.28250
# [298]	validation_0-mlogloss:0.28252
# [299]	validation_0-mlogloss:0.28254
# [300]	validation_0-mlogloss:0.28254
# [301]	validation_0-mlogloss:0.28254
# [302]	validation_0-mlogloss:0.28256
# [303]	validation_0-mlogloss:0.28261
# [304]	validation_0-mlogloss:0.28261
# [305]	validation_0-mlogloss:0.28261
# [306]	validation_0-mlogloss:0.28262
# [307]	validation_0-mlogloss:0.28260
# [308]	validation_0-mlogloss:0.28260
# [309]	validation_0-mlogloss:0.28260
# [310]	validation_0-mlogloss:0.28259
# [311]	validation_0-mlogloss:0.28256
# [312]	validation_0-mlogloss:0.28255
# [313]	validation_0-mlogloss:0.28255
# [314]	validation_0-mlogloss:0.28255
# [315]	validation_0-mlogloss:0.28253
# [316]	validation_0-mlogloss:0.28250
# [317]	validation_0-mlogloss:0.28250
# [318]	validation_0-mlogloss:0.28246
# [319]	validation_0-mlogloss:0.28245
# [320]	validation_0-mlogloss:0.28246
# [321]	validation_0-mlogloss:0.28244
# [322]	validation_0-mlogloss:0.28243
# [323]	validation_0-mlogloss:0.28243
# [324]	validation_0-mlogloss:0.28247
# [325]	validation_0-mlogloss:0.28239
# [326]	validation_0-mlogloss:0.28240
# [327]	validation_0-mlogloss:0.28233
# [328]	validation_0-mlogloss:0.28236
# [329]	validation_0-mlogloss:0.28235
# [330]	validation_0-mlogloss:0.28234
# [331]	validation_0-mlogloss:0.28233
# [332]	validation_0-mlogloss:0.28227
# [333]	validation_0-mlogloss:0.28226
# [334]	validation_0-mlogloss:0.28233
# [335]	validation_0-mlogloss:0.28235
# [336]	validation_0-mlogloss:0.28237
# [337]	validation_0-mlogloss:0.28235
# [338]	validation_0-mlogloss:0.28237
# [339]	validation_0-mlogloss:0.28238
# [340]	validation_0-mlogloss:0.28237
# [341]	validation_0-mlogloss:0.28238
# [342]	validation_0-mlogloss:0.28248
# [343]	validation_0-mlogloss:0.28250
# [344]	validation_0-mlogloss:0.28249
# [345]	validation_0-mlogloss:0.28256
# [346]	validation_0-mlogloss:0.28255
# [347]	validation_0-mlogloss:0.28258
# [348]	validation_0-mlogloss:0.28258
# [349]	validation_0-mlogloss:0.28258
# [350]	validation_0-mlogloss:0.28258
# [351]	validation_0-mlogloss:0.28258
# [352]	validation_0-mlogloss:0.28258
# [353]	validation_0-mlogloss:0.28259
# [354]	validation_0-mlogloss:0.28258
# [355]	validation_0-mlogloss:0.28256
# [356]	validation_0-mlogloss:0.28255
# [357]	validation_0-mlogloss:0.28255
# [358]	validation_0-mlogloss:0.28257
# [359]	validation_0-mlogloss:0.28253
# [360]	validation_0-mlogloss:0.28253
# [361]	validation_0-mlogloss:0.28244
# [362]	validation_0-mlogloss:0.28249
# [363]	validation_0-mlogloss:0.28248
# [364]	validation_0-mlogloss:0.28248
# [365]	validation_0-mlogloss:0.28254
# [366]	validation_0-mlogloss:0.28244
# [367]	validation_0-mlogloss:0.28245
# [368]	validation_0-mlogloss:0.28245
# [369]	validation_0-mlogloss:0.28244
# [370]	validation_0-mlogloss:0.28246
# [371]	validation_0-mlogloss:0.28253
# [372]	validation_0-mlogloss:0.28254
# [373]	validation_0-mlogloss:0.28255
# [374]	validation_0-mlogloss:0.28255
# [375]	validation_0-mlogloss:0.28255
# [376]	validation_0-mlogloss:0.28256
# [377]	validation_0-mlogloss:0.28254
# [378]	validation_0-mlogloss:0.28253
# [379]	validation_0-mlogloss:0.28239
# [380]	validation_0-mlogloss:0.28240
# [381]	validation_0-mlogloss:0.28244
# [382]	validation_0-mlogloss:0.28241
# [383]	validation_0-mlogloss:0.28242
# [384]	validation_0-mlogloss:0.28242
# [385]	validation_0-mlogloss:0.28242
# [386]	validation_0-mlogloss:0.28244
# [387]	validation_0-mlogloss:0.28245
# [388]	validation_0-mlogloss:0.28244
# [389]	validation_0-mlogloss:0.28244
# [390]	validation_0-mlogloss:0.28242
# [391]	validation_0-mlogloss:0.28241
# [392]	validation_0-mlogloss:0.28236
# [393]	validation_0-mlogloss:0.28238
# [394]	validation_0-mlogloss:0.28241
# [395]	validation_0-mlogloss:0.28243
# [396]	validation_0-mlogloss:0.28243
# [397]	validation_0-mlogloss:0.28242
# [398]	validation_0-mlogloss:0.28243
# [399]	validation_0-mlogloss:0.28245
# [400]	validation_0-mlogloss:0.28246
# [401]	validation_0-mlogloss:0.28245
# [402]	validation_0-mlogloss:0.28244
# [403]	validation_0-mlogloss:0.28242
# [404]	validation_0-mlogloss:0.28242
# [405]	validation_0-mlogloss:0.28242
# [406]	validation_0-mlogloss:0.28240
# [407]	validation_0-mlogloss:0.28238
# [408]	validation_0-mlogloss:0.28239
# [409]	validation_0-mlogloss:0.28237
# [410]	validation_0-mlogloss:0.28235
# [411]	validation_0-mlogloss:0.28236
# [412]	validation_0-mlogloss:0.28235
# [413]	validation_0-mlogloss:0.28235
# [414]	validation_0-mlogloss:0.28233
# [415]	validation_0-mlogloss:0.28234
# [416]	validation_0-mlogloss:0.28234
# [417]	validation_0-mlogloss:0.28235
# [418]	validation_0-mlogloss:0.28235
# [419]	validation_0-mlogloss:0.28235
# [420]	validation_0-mlogloss:0.28231
# [421]	validation_0-mlogloss:0.28233
# [422]	validation_0-mlogloss:0.28231
# [423]	validation_0-mlogloss:0.28230
# [424]	validation_0-mlogloss:0.28231
# [425]	validation_0-mlogloss:0.28234
# [426]	validation_0-mlogloss:0.28232
# [427]	validation_0-mlogloss:0.28234
# [428]	validation_0-mlogloss:0.28235
# [429]	validation_0-mlogloss:0.28237
# [430]	validation_0-mlogloss:0.28238
# [431]	validation_0-mlogloss:0.28237
# [432]	validation_0-mlogloss:0.28238
# [433]	validation_0-mlogloss:0.28240
# [434]	validation_0-mlogloss:0.28241
# [435]	validation_0-mlogloss:0.28241
# [436]	validation_0-mlogloss:0.28242
# [437]	validation_0-mlogloss:0.28242
# [438]	validation_0-mlogloss:0.28240
# [439]	validation_0-mlogloss:0.28240
# [440]	validation_0-mlogloss:0.28242
# [441]	validation_0-mlogloss:0.28241
# [442]	validation_0-mlogloss:0.28242
# [443]	validation_0-mlogloss:0.28243
# [444]	validation_0-mlogloss:0.28240
# [445]	validation_0-mlogloss:0.28241
# [446]	validation_0-mlogloss:0.28259
# [447]	validation_0-mlogloss:0.28259
# [448]	validation_0-mlogloss:0.28260
# [449]	validation_0-mlogloss:0.28260
# [450]	validation_0-mlogloss:0.28261
# [451]	validation_0-mlogloss:0.28259
# [452]	validation_0-mlogloss:0.28258
# [453]	validation_0-mlogloss:0.28245
# [454]	validation_0-mlogloss:0.28245
# [455]	validation_0-mlogloss:0.28245
# [456]	validation_0-mlogloss:0.28244
# [457]	validation_0-mlogloss:0.28240
# [458]	validation_0-mlogloss:0.28239
# [459]	validation_0-mlogloss:0.28231
# [460]	validation_0-mlogloss:0.28233
# [461]	validation_0-mlogloss:0.28234
# [462]	validation_0-mlogloss:0.28235
# [463]	validation_0-mlogloss:0.28233
# [464]	validation_0-mlogloss:0.28232
# [465]	validation_0-mlogloss:0.28231
# [466]	validation_0-mlogloss:0.28231
# [467]	validation_0-mlogloss:0.28229
# [468]	validation_0-mlogloss:0.28231
# [469]	validation_0-mlogloss:0.28233
# [470]	validation_0-mlogloss:0.28235
# [471]	validation_0-mlogloss:0.28229
# [472]	validation_0-mlogloss:0.28232
# [473]	validation_0-mlogloss:0.28230
# [474]	validation_0-mlogloss:0.28230
# [475]	validation_0-mlogloss:0.28234
# [476]	validation_0-mlogloss:0.28235
# [477]	validation_0-mlogloss:0.28232
# [478]	validation_0-mlogloss:0.28231
# [479]	validation_0-mlogloss:0.28230
# [480]	validation_0-mlogloss:0.28232
# [481]	validation_0-mlogloss:0.28232
# [482]	validation_0-mlogloss:0.28232
# [483]	validation_0-mlogloss:0.28232
# [484]	validation_0-mlogloss:0.28228
# [485]	validation_0-mlogloss:0.28227
# [486]	validation_0-mlogloss:0.28226
# [487]	validation_0-mlogloss:0.28226
# [488]	validation_0-mlogloss:0.28226
# [489]	validation_0-mlogloss:0.28224
# [490]	validation_0-mlogloss:0.28224
# [491]	validation_0-mlogloss:0.28232
# [492]	validation_0-mlogloss:0.28233
# [493]	validation_0-mlogloss:0.28231
# [494]	validation_0-mlogloss:0.28233
# [495]	validation_0-mlogloss:0.28231
# [496]	validation_0-mlogloss:0.28233
# [497]	validation_0-mlogloss:0.28234
# [498]	validation_0-mlogloss:0.28232
# [499]	validation_0-mlogloss:0.28231
# [500]	validation_0-mlogloss:0.28232
# [501]	validation_0-mlogloss:0.28230
# [502]	validation_0-mlogloss:0.28228
# [503]	validation_0-mlogloss:0.28227
# [504]	validation_0-mlogloss:0.28226
# [505]	validation_0-mlogloss:0.28225
# [506]	validation_0-mlogloss:0.28226
# [507]	validation_0-mlogloss:0.28223
# [508]	validation_0-mlogloss:0.28225
# [509]	validation_0-mlogloss:0.28226
# [510]	validation_0-mlogloss:0.28229
# [511]	validation_0-mlogloss:0.28230
# [512]	validation_0-mlogloss:0.28231
# [513]	validation_0-mlogloss:0.28230
# [514]	validation_0-mlogloss:0.28229
# [515]	validation_0-mlogloss:0.28227
# [516]	validation_0-mlogloss:0.28231
# [517]	validation_0-mlogloss:0.28231
# [518]	validation_0-mlogloss:0.28232
# [519]	validation_0-mlogloss:0.28233
# [520]	validation_0-mlogloss:0.28231
# [521]	validation_0-mlogloss:0.28232
# [522]	validation_0-mlogloss:0.28233
# [523]	validation_0-mlogloss:0.28231
# [524]	validation_0-mlogloss:0.28231
# [525]	validation_0-mlogloss:0.28232
# [526]	validation_0-mlogloss:0.28232
# [527]	validation_0-mlogloss:0.28230
# [528]	validation_0-mlogloss:0.28232
# [529]	validation_0-mlogloss:0.28232
# [530]	validation_0-mlogloss:0.28233
# [531]	validation_0-mlogloss:0.28233
# [532]	validation_0-mlogloss:0.28236
# [533]	validation_0-mlogloss:0.28234
# [534]	validation_0-mlogloss:0.28233
# [535]	validation_0-mlogloss:0.28235
# [536]	validation_0-mlogloss:0.28238
# [537]	validation_0-mlogloss:0.28241
# [538]	validation_0-mlogloss:0.28240
# [539]	validation_0-mlogloss:0.28239
#
# ✅ XGBoost Results (Tuned)
# Accuracy: 0.9067796610169492
# Macro-F1: 0.7579053874057687
#                         precision    recall  f1-score   support
#
#        aggressive-scan       0.72      0.72      0.72        18
#          cryptojacking       1.00      1.00      1.00       165
#             icmp-flood       0.65      0.85      0.73        13
#     icmp-fragmentation       1.00      1.00      1.00        13
# icmp-fragmentation_old       0.33      0.17      0.22         6
#                   none       1.00      1.00      1.00       220
#      os-fingerprinting       0.67      0.77      0.71        13
#                os-scan       0.67      0.67      0.67         6
#              port-scan       0.63      0.63      0.63        19
#         push-ack-flood       1.00      1.00      1.00        12
#       serice-detection       0.67      0.67      0.67         6
#      service-detection       0.42      0.36      0.38        14
#              syn-flood       1.00      1.00      1.00        13
#            syn-stealth       0.61      0.65      0.63        17
#    synonymous-ip-flood       1.00      0.92      0.96        12
#              tcp-flood       1.00      0.92      0.96        12
#              udp-flood       1.00      0.83      0.91        12
#              vuln-scan       0.43      0.47      0.45        19
#
#               accuracy                           0.91       590
#              macro avg       0.77      0.76      0.76       590
#           weighted avg       0.91      0.91      0.91       590
# /tmp/ipython-input-1542410286.py:149: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, X_test_all[:200], feature_names=[f"f{i}" for i in range(X_test_all.shape[1])])
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:723: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# 📂 Saved: tuned model results, confusion matrix, F1 plots, SHAP plots
